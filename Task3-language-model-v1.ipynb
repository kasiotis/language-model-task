# %% [markdown]
# # Data Preparation

# %%
# importing required libraries
import requests
import string
import tensorflow as tf
import re

# %% [markdown]
# Downloading the book, turning it into text format and displaying its first 20 lines to see what it consists of.

# %%
# Getting the text form the internet
response = requests.get("https://www.gutenberg.org/files/61262/61262-0.txt",)
# turing the file into text and splitting it at every new line
data = response.text.split('\n')
# printing the first 20 lines of the raw text
data[:20]
# Out:
# ['ï»¿The Project Gutenberg EBook of Poirot Investigates, by Agatha Christie\r',
#  '\r',
#  'This eBook is for the use of anyone anywhere in the United States and most\r',
#  'other parts of the world at no cost and with almost no restrictions\r',
#  'whatsoever.  You may copy it, give it away or re-use it under the terms of\r',
#  'the Project Gutenberg License included with this eBook or online at\r',
#  "www.gutenberg.org.  If you are not located in the United States, you'll have\r",
#  'to check the laws of the country where you are located before using this ebook.\r',
#  '\r',
#  'Title: Poirot Investigates\r',
#  '\r',
#  'Author: Agatha Christie\r',
#  '\r',
#  'Release Date: January 28, 2020 [EBook #61262]\r',
#  '[Last updated: June 20, 2022]\r',
#  '\r',
#  'Language: English\r',
#  '\r',
#  'Character set encoding: UTF-8\r',
#  '\r']

# %% [markdown]
# Creating a function to clean the ebook by removing all unnecessary characters and to also separate the text into individual word tokens

# %%
# Function for cleaning the ebook and separating the text into individual word tokens
def clean (document):

    #only keeping the lines that correspond to the text of the book
    document = document[112:7600]
    # list of lines converted into text
    document = " ".join(document)
    # turning the text into lowercase letters only 
    document = document.lower()
    # removing carriage return characters
    document = document.replace('\r', '') 
    # removing all other extra spaces
    document = re.sub('\s+', ' ', document)
    # removing special characters
    document = re.sub(r'[^\x00-\x7f]', r'', document) 
    # Removing the punctuation
    table = str.maketrans('', '', string.punctuation)
    document = document.translate(table)

    # setting each "word" to be a token by spliting the text based on whitespace
    tokens = document.split()

    return tokens

# %% [markdown]
# Getting my text data cleaned using the function I created above and previewing my tokenized words from my text

# %%
tokens = clean(data)
# printing the first 50 words of the text after cleaning
print(tokens[:50])
# Out:
# ['i', 'was', 'standing', 'at', 'the', 'window', 'of', 'poirots', 'rooms', 'looking', 'out', 'idly', 'on', 'the', 'street', 'below', 'thats', 'queer', 'i', 'ejaculated', 'suddenly', 'beneath', 'my', 'breath', 'what', 'is', 'mon', 'ami', 'asked', 'poirot', 'placidly', 'from', 'the', 'depths', 'of', 'his', 'comfortable', 'chair', 'deduce', 'poirot', 'from', 'the', 'following', 'facts', 'here', 'is', 'a', 'young', 'lady', 'richly']

# %%
# Total number of words
all_words = len(tokens)
print("Total words: ", all_words)
# Out:
# Total words:  52355

# %%
# unique words
unq_words = len(set(tokens))
print("Unique words: ", unq_words)
# Out:
# Unique words:  6277

# %% [markdown]
# Creating a list of multiple 41-word sequences that will be used to train the model. The first 40 words in each sequence are for training and the last one is for validating the prediciton

# %%
# 41 words to be used in the model, 
# the first 40 words are for training and the last one for validating the prediciton
length = 40 + 1
sentence_set = []

for i in range(length, len(tokens)):
    # taking a sequence of words for each chunk of 41 words in the whole text
    sequence = tokens[i-length:i]
    # joining the individual tokens (words) into a line (string)
    line = ' '.join(sequence)
    # adding my sentence (line of 41 words) into my "lines" list
    sentence_set.append(line)

print(len(sentence_set))
# Out:
# 52312

# %%
# previewing some of the lines
sentence_set[:3]
# Out:
# ['i was standing at the window of poirots rooms looking out idly on the street below thats queer i ejaculated suddenly beneath my breath what is mon ami asked poirot placidly from the depths of his comfortable chair deduce poirot from',
#  'was standing at the window of poirots rooms looking out idly on the street below thats queer i ejaculated suddenly beneath my breath what is mon ami asked poirot placidly from the depths of his comfortable chair deduce poirot from the',
#  'standing at the window of poirots rooms looking out idly on the street below thats queer i ejaculated suddenly beneath my breath what is mon ami asked poirot placidly from the depths of his comfortable chair deduce poirot from the following']

# %% [markdown]
# # Building my Model

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
import numpy as np

# %% [markdown]
# Preparing x and y for the words

# %%
# initializing the tokenizer object
tokenizer = Tokenizer()
# using tokenizer to turn every unique word into a unique integer
tokenizer.fit_on_texts(sentence_set)
# Creating a list of integer values for all our sentences
sequences_int = tokenizer.texts_to_sequences(sentence_set)
sequences_int = np.array(sequences_int)
# selecting the first 40 columns a my predictor variabls 
X = sequences_int[:, :-1] ### (there are 30 integers representing words)
# selecting the last (41st) column as my response variable 
y = sequences_int[:, -1] ### (there are 30 integers representing words)

# Turning my response variable into one-hot encoding
y = to_categorical(y, num_classes= len(tokenizer.word_index)+1)

# %%
model = Sequential()
# amount of unique words as inputs and amount of required predicted words as output
model.add(Embedding(unq_words+1, 50, input_length = X.shape[1]))
model.add(LSTM(64, return_sequences = True))
model.add(LSTM(128))
model.add(Dense(128, activation='relu'))
# output layers with softmax for probability of each predicted word
model.add(Dense(unq_words+1, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 40, 50)            313900
#
#  lstm_2 (LSTM)               (None, 40, 64)            29440
#
#  lstm_3 (LSTM)               (None, 128)               98816
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 6278)              809862
#
# =================================================================
# Total params: 1,268,530
# Trainable params: 1,268,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model with adam optimizer and fitting it.
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
lstm_history = model.fit(X, y, batch_size = 128, epochs=500)
# Out:
# Epoch 1/500
# 409/409 [==============================] - 9s 15ms/step - loss: 6.8058 - accuracy: 0.0568
# Epoch 2/500
# 409/409 [==============================] - 6s 14ms/step - loss: 6.3818 - accuracy: 0.0610
# Epoch 3/500
# 409/409 [==============================] - 6s 14ms/step - loss: 6.1832 - accuracy: 0.0694
# Epoch 4/500
# 409/409 [==============================] - 6s 14ms/step - loss: 6.0424 - accuracy: 0.0739
# Epoch 5/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.9096 - accuracy: 0.0788
# Epoch 6/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.7897 - accuracy: 0.0853
# Epoch 7/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.6793 - accuracy: 0.0905
# Epoch 8/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.5798 - accuracy: 0.0955
# Epoch 9/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.4863 - accuracy: 0.1017
# Epoch 10/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.3982 - accuracy: 0.1057
# Epoch 11/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.3107 - accuracy: 0.1109
# Epoch 12/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.2235 - accuracy: 0.1138
# Epoch 13/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.1369 - accuracy: 0.1173
# Epoch 14/500
# 409/409 [==============================] - 6s 14ms/step - loss: 5.0508 - accuracy: 0.1200
# Epoch 15/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.9669 - accuracy: 0.1258
# Epoch 16/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.8841 - accuracy: 0.1297
# Epoch 17/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.8026 - accuracy: 0.1326
# Epoch 18/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.7217 - accuracy: 0.1373
# Epoch 19/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.6430 - accuracy: 0.1407
# Epoch 20/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.5649 - accuracy: 0.1457
# Epoch 21/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.4878 - accuracy: 0.1491
# Epoch 22/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.4120 - accuracy: 0.1531
# Epoch 23/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.3390 - accuracy: 0.1588
# Epoch 24/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.2689 - accuracy: 0.1620
# Epoch 25/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.1973 - accuracy: 0.1671
# Epoch 26/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.1308 - accuracy: 0.1734
# Epoch 27/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.0653 - accuracy: 0.1802
# Epoch 28/500
# 409/409 [==============================] - 6s 14ms/step - loss: 4.0032 - accuracy: 0.1853
# Epoch 29/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.9478 - accuracy: 0.1922
# Epoch 30/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.8903 - accuracy: 0.1974
# Epoch 31/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.8311 - accuracy: 0.2042
# Epoch 32/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.7824 - accuracy: 0.2107
# Epoch 33/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.7318 - accuracy: 0.2162
# Epoch 34/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.6789 - accuracy: 0.2247
# Epoch 35/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.6306 - accuracy: 0.2292
# Epoch 36/500
# 409/409 [==============================] - 6s 15ms/step - loss: 3.5891 - accuracy: 0.2337
# Epoch 37/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.5455 - accuracy: 0.2410
# Epoch 38/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.5014 - accuracy: 0.2485
# Epoch 39/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.4603 - accuracy: 0.2515
# Epoch 40/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.4210 - accuracy: 0.2582
# Epoch 41/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.3788 - accuracy: 0.2662
# Epoch 42/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.3412 - accuracy: 0.2711
# Epoch 43/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.3044 - accuracy: 0.2779
# Epoch 44/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.2701 - accuracy: 0.2835
# Epoch 45/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.2301 - accuracy: 0.2873
# Epoch 46/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.1983 - accuracy: 0.2928
# Epoch 47/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.1654 - accuracy: 0.2980
# Epoch 48/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.1325 - accuracy: 0.3033
# Epoch 49/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.1008 - accuracy: 0.3109
# Epoch 50/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.0667 - accuracy: 0.3143
# Epoch 51/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.0378 - accuracy: 0.3209
# Epoch 52/500
# 409/409 [==============================] - 6s 14ms/step - loss: 3.0128 - accuracy: 0.3222
# Epoch 53/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.9752 - accuracy: 0.3297
# Epoch 54/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.9424 - accuracy: 0.3348
# Epoch 55/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.9185 - accuracy: 0.3385
# Epoch 56/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.8909 - accuracy: 0.3451
# Epoch 57/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.8548 - accuracy: 0.3511
# Epoch 58/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.8315 - accuracy: 0.3543
# Epoch 59/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.8050 - accuracy: 0.3592
# Epoch 60/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.7761 - accuracy: 0.3649
# Epoch 61/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.7460 - accuracy: 0.3691
# Epoch 62/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.7223 - accuracy: 0.3752
# Epoch 63/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.6997 - accuracy: 0.3770
# Epoch 64/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.6734 - accuracy: 0.3847
# Epoch 65/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.6506 - accuracy: 0.3893
# Epoch 66/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.6237 - accuracy: 0.3940
# Epoch 67/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.5975 - accuracy: 0.3989
# Epoch 68/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.5744 - accuracy: 0.4025
# Epoch 69/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.5492 - accuracy: 0.4083
# Epoch 70/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.5245 - accuracy: 0.4114
# Epoch 71/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.4987 - accuracy: 0.4159
# Epoch 72/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.4782 - accuracy: 0.4186
# Epoch 73/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.4630 - accuracy: 0.4220
# Epoch 74/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.4346 - accuracy: 0.4293
# Epoch 75/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.4111 - accuracy: 0.4330
# Epoch 76/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.3908 - accuracy: 0.4364
# Epoch 77/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.3701 - accuracy: 0.4413
# Epoch 78/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.3446 - accuracy: 0.4467
# Epoch 79/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.3258 - accuracy: 0.4507
# Epoch 80/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.3091 - accuracy: 0.4535
# Epoch 81/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.2874 - accuracy: 0.4579
# Epoch 82/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.2596 - accuracy: 0.4640
# Epoch 83/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.2404 - accuracy: 0.4652
# Epoch 84/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.2238 - accuracy: 0.4709
# Epoch 85/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.2072 - accuracy: 0.4739
# Epoch 86/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.1879 - accuracy: 0.4766
# Epoch 87/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.1643 - accuracy: 0.4830
# Epoch 88/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.1502 - accuracy: 0.4856
# Epoch 89/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.1314 - accuracy: 0.4893
# Epoch 90/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.1102 - accuracy: 0.4952
# Epoch 91/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.0948 - accuracy: 0.4991
# Epoch 92/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.0711 - accuracy: 0.5014
# Epoch 93/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.0594 - accuracy: 0.5060
# Epoch 94/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.0416 - accuracy: 0.5085
# Epoch 95/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.0235 - accuracy: 0.5101
# Epoch 96/500
# 409/409 [==============================] - 6s 14ms/step - loss: 2.0075 - accuracy: 0.5145
# Epoch 97/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.9864 - accuracy: 0.5193
# Epoch 98/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.9684 - accuracy: 0.5246
# Epoch 99/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.9580 - accuracy: 0.5248
# Epoch 100/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.9409 - accuracy: 0.5291
# Epoch 101/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.9196 - accuracy: 0.5345
# Epoch 102/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.9027 - accuracy: 0.5378
# Epoch 103/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.8876 - accuracy: 0.5421
# Epoch 104/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.8676 - accuracy: 0.5456
# Epoch 105/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.8544 - accuracy: 0.5497
# Epoch 106/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.8439 - accuracy: 0.5512
# Epoch 107/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.8276 - accuracy: 0.5527
# Epoch 108/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.8112 - accuracy: 0.5561
# Epoch 109/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.7976 - accuracy: 0.5587
# Epoch 110/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.7758 - accuracy: 0.5676
# Epoch 111/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.7692 - accuracy: 0.5671
# Epoch 112/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.7469 - accuracy: 0.5707
# Epoch 113/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.7321 - accuracy: 0.5750
# Epoch 114/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.7135 - accuracy: 0.5800
# Epoch 115/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.7044 - accuracy: 0.5830
# Epoch 116/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.6940 - accuracy: 0.5834
# Epoch 117/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.6835 - accuracy: 0.5878
# Epoch 118/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.6565 - accuracy: 0.5929
# Epoch 119/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.6443 - accuracy: 0.5969
# Epoch 120/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.6342 - accuracy: 0.5953
# Epoch 121/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.6183 - accuracy: 0.5992
# Epoch 122/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.6106 - accuracy: 0.6024
# Epoch 123/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.5881 - accuracy: 0.6070
# Epoch 124/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.5761 - accuracy: 0.6080
# Epoch 125/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.5686 - accuracy: 0.6107
# Epoch 126/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.5474 - accuracy: 0.6172
# Epoch 127/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.5380 - accuracy: 0.6181
# Epoch 128/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.5316 - accuracy: 0.6193
# Epoch 129/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.5164 - accuracy: 0.6214
# Epoch 130/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.4935 - accuracy: 0.6281
# Epoch 131/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.4902 - accuracy: 0.6291
# Epoch 132/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.4806 - accuracy: 0.6305
# Epoch 133/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.4624 - accuracy: 0.6358
# Epoch 134/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.4468 - accuracy: 0.6389
# Epoch 135/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.4402 - accuracy: 0.6402
# Epoch 136/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.4241 - accuracy: 0.6432
# Epoch 137/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.4083 - accuracy: 0.6480
# Epoch 138/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3967 - accuracy: 0.6503
# Epoch 139/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3910 - accuracy: 0.6517
# Epoch 140/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3852 - accuracy: 0.6525
# Epoch 141/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3617 - accuracy: 0.6591
# Epoch 142/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3559 - accuracy: 0.6592
# Epoch 143/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3479 - accuracy: 0.6610
# Epoch 144/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3382 - accuracy: 0.6637
# Epoch 145/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3144 - accuracy: 0.6698
# Epoch 146/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.3046 - accuracy: 0.6709
# Epoch 147/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2910 - accuracy: 0.6734
# Epoch 148/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2853 - accuracy: 0.6773
# Epoch 149/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2761 - accuracy: 0.6766
# Epoch 150/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2609 - accuracy: 0.6817
# Epoch 151/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2510 - accuracy: 0.6844
# Epoch 152/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2464 - accuracy: 0.6839
# Epoch 153/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2307 - accuracy: 0.6885
# Epoch 154/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2279 - accuracy: 0.6877
# Epoch 155/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.2132 - accuracy: 0.6933
# Epoch 156/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1934 - accuracy: 0.6985
# Epoch 157/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1843 - accuracy: 0.6996
# Epoch 158/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1788 - accuracy: 0.7010
# Epoch 159/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1725 - accuracy: 0.7034
# Epoch 160/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1532 - accuracy: 0.7077
# Epoch 161/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1514 - accuracy: 0.7093
# Epoch 162/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1392 - accuracy: 0.7106
# Epoch 163/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1250 - accuracy: 0.7152
# Epoch 164/500
# 409/409 [==============================] - 6s 15ms/step - loss: 1.1238 - accuracy: 0.7143
# Epoch 165/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1133 - accuracy: 0.7168
# Epoch 166/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.1087 - accuracy: 0.7155
# Epoch 167/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0862 - accuracy: 0.7232
# Epoch 168/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0752 - accuracy: 0.7264
# Epoch 169/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0649 - accuracy: 0.7286
# Epoch 170/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0622 - accuracy: 0.7285
# Epoch 171/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0592 - accuracy: 0.7289
# Epoch 172/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0481 - accuracy: 0.7327
# Epoch 173/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0385 - accuracy: 0.7336
# Epoch 174/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0196 - accuracy: 0.7409
# Epoch 175/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0134 - accuracy: 0.7409
# Epoch 176/500
# 409/409 [==============================] - 6s 14ms/step - loss: 1.0035 - accuracy: 0.7431
# Epoch 177/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9868 - accuracy: 0.7477
# Epoch 178/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9983 - accuracy: 0.7443
# Epoch 179/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9873 - accuracy: 0.7478
# Epoch 180/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9662 - accuracy: 0.7528
# Epoch 181/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9562 - accuracy: 0.7532
# Epoch 182/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9521 - accuracy: 0.7551
# Epoch 183/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9406 - accuracy: 0.7583
# Epoch 184/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9416 - accuracy: 0.7588
# Epoch 185/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9269 - accuracy: 0.7607
# Epoch 186/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9211 - accuracy: 0.7628
# Epoch 187/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9139 - accuracy: 0.7659
# Epoch 188/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.9039 - accuracy: 0.7659
# Epoch 189/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8992 - accuracy: 0.7683
# Epoch 190/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8846 - accuracy: 0.7719
# Epoch 191/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8716 - accuracy: 0.7773
# Epoch 192/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8772 - accuracy: 0.7745
# Epoch 193/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8594 - accuracy: 0.7771
# Epoch 194/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8418 - accuracy: 0.7830
# Epoch 195/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8448 - accuracy: 0.7823
# Epoch 196/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8446 - accuracy: 0.7810
# Epoch 197/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8403 - accuracy: 0.7826
# Epoch 198/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8444 - accuracy: 0.7809
# Epoch 199/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.8137 - accuracy: 0.7903
# Epoch 200/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7964 - accuracy: 0.7962
# Epoch 201/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7884 - accuracy: 0.7975
# Epoch 202/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7824 - accuracy: 0.7980
# Epoch 203/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7900 - accuracy: 0.7939
# Epoch 204/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7881 - accuracy: 0.7974
# Epoch 205/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7763 - accuracy: 0.8000
# Epoch 206/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7709 - accuracy: 0.8011
# Epoch 207/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7458 - accuracy: 0.8073
# Epoch 208/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7598 - accuracy: 0.8032
# Epoch 209/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7471 - accuracy: 0.8061
# Epoch 210/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7476 - accuracy: 0.8051
# Epoch 211/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7367 - accuracy: 0.8085
# Epoch 212/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7175 - accuracy: 0.8143
# Epoch 213/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.7049 - accuracy: 0.8184
# Epoch 214/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6942 - accuracy: 0.8207
# Epoch 215/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6897 - accuracy: 0.8215
# Epoch 216/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6953 - accuracy: 0.8192
# Epoch 217/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6960 - accuracy: 0.8193
# Epoch 218/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6877 - accuracy: 0.8206
# Epoch 219/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6778 - accuracy: 0.8232
# Epoch 220/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6698 - accuracy: 0.8255
# Epoch 221/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6635 - accuracy: 0.8291
# Epoch 222/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6436 - accuracy: 0.8334
# Epoch 223/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6440 - accuracy: 0.8328
# Epoch 224/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6343 - accuracy: 0.8351
# Epoch 225/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6300 - accuracy: 0.8378
# Epoch 226/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6223 - accuracy: 0.8370
# Epoch 227/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6345 - accuracy: 0.8333
# Epoch 228/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6229 - accuracy: 0.8368
# Epoch 229/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6167 - accuracy: 0.8392
# Epoch 230/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6300 - accuracy: 0.8342
# Epoch 231/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.6026 - accuracy: 0.8421
# Epoch 232/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5745 - accuracy: 0.8520
# Epoch 233/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5970 - accuracy: 0.8442
# Epoch 234/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5912 - accuracy: 0.8433
# Epoch 235/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5794 - accuracy: 0.8493
# Epoch 236/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5621 - accuracy: 0.8541
# Epoch 237/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5548 - accuracy: 0.8575
# Epoch 238/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5641 - accuracy: 0.8529
# Epoch 239/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5591 - accuracy: 0.8526
# Epoch 240/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5521 - accuracy: 0.8568
# Epoch 241/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5397 - accuracy: 0.8596
# Epoch 242/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5432 - accuracy: 0.8562
# Epoch 243/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5610 - accuracy: 0.8504
# Epoch 244/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5417 - accuracy: 0.8591
# Epoch 245/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5117 - accuracy: 0.8678
# Epoch 246/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4963 - accuracy: 0.8709
# Epoch 247/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5087 - accuracy: 0.8681
# Epoch 248/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5181 - accuracy: 0.8637
# Epoch 249/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5089 - accuracy: 0.8657
# Epoch 250/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4988 - accuracy: 0.8704
# Epoch 251/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4902 - accuracy: 0.8718
# Epoch 252/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4884 - accuracy: 0.8713
# Epoch 253/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5184 - accuracy: 0.8637
# Epoch 254/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5475 - accuracy: 0.8523
# Epoch 255/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.5054 - accuracy: 0.8648
# Epoch 256/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4470 - accuracy: 0.8840
# Epoch 257/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4339 - accuracy: 0.8898
# Epoch 258/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4390 - accuracy: 0.8876
# Epoch 259/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4525 - accuracy: 0.8824
# Epoch 260/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4673 - accuracy: 0.8783
# Epoch 261/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4527 - accuracy: 0.8809
# Epoch 262/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4632 - accuracy: 0.8780
# Epoch 263/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4411 - accuracy: 0.8844
# Epoch 264/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4349 - accuracy: 0.8861
# Epoch 265/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4348 - accuracy: 0.8853
# Epoch 266/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4240 - accuracy: 0.8882
# Epoch 267/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4255 - accuracy: 0.8887
# Epoch 268/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4294 - accuracy: 0.8858
# Epoch 269/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4293 - accuracy: 0.8873
# Epoch 270/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4233 - accuracy: 0.8864
# Epoch 271/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3891 - accuracy: 0.8993
# Epoch 272/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3743 - accuracy: 0.9053
# Epoch 273/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3892 - accuracy: 0.8989
# Epoch 274/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4150 - accuracy: 0.8896
# Epoch 275/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.4143 - accuracy: 0.8897
# Epoch 276/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3983 - accuracy: 0.8955
# Epoch 277/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3839 - accuracy: 0.9014
# Epoch 278/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3857 - accuracy: 0.8991
# Epoch 279/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3708 - accuracy: 0.9031
# Epoch 280/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3652 - accuracy: 0.9057
# Epoch 281/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3736 - accuracy: 0.9028
# Epoch 282/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3640 - accuracy: 0.9040
# Epoch 283/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3760 - accuracy: 0.8998
# Epoch 284/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3910 - accuracy: 0.8948
# Epoch 285/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3812 - accuracy: 0.8993
# Epoch 286/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3719 - accuracy: 0.9022
# Epoch 287/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3348 - accuracy: 0.9134
# Epoch 288/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3174 - accuracy: 0.9206
# Epoch 289/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3086 - accuracy: 0.9216
# Epoch 290/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3252 - accuracy: 0.9159
# Epoch 291/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3545 - accuracy: 0.9048
# Epoch 292/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3729 - accuracy: 0.8997
# Epoch 293/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3775 - accuracy: 0.8976
# Epoch 294/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3448 - accuracy: 0.9082
# Epoch 295/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3271 - accuracy: 0.9144
# Epoch 296/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2964 - accuracy: 0.9238
# Epoch 297/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2772 - accuracy: 0.9310
# Epoch 298/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2994 - accuracy: 0.9233
# Epoch 299/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3163 - accuracy: 0.9164
# Epoch 300/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3322 - accuracy: 0.9116
# Epoch 301/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3504 - accuracy: 0.9034
# Epoch 302/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3159 - accuracy: 0.9153
# Epoch 303/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2788 - accuracy: 0.9293
# Epoch 304/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2624 - accuracy: 0.9338
# Epoch 305/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3097 - accuracy: 0.9177
# Epoch 306/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3198 - accuracy: 0.9141
# Epoch 307/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3046 - accuracy: 0.9187
# Epoch 308/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2866 - accuracy: 0.9254
# Epoch 309/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2695 - accuracy: 0.9295
# Epoch 310/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2755 - accuracy: 0.9296
# Epoch 311/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2827 - accuracy: 0.9248
# Epoch 312/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2730 - accuracy: 0.9286
# Epoch 313/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2775 - accuracy: 0.9273
# Epoch 314/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3087 - accuracy: 0.9166
# Epoch 315/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2991 - accuracy: 0.9189
# Epoch 316/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2674 - accuracy: 0.9298
# Epoch 317/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2602 - accuracy: 0.9312
# Epoch 318/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2438 - accuracy: 0.9390
# Epoch 319/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2584 - accuracy: 0.9321
# Epoch 320/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2729 - accuracy: 0.9273
# Epoch 321/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2920 - accuracy: 0.9207
# Epoch 322/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2751 - accuracy: 0.9268
# Epoch 323/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2421 - accuracy: 0.9372
# Epoch 324/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2226 - accuracy: 0.9444
# Epoch 325/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2341 - accuracy: 0.9408
# Epoch 326/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2526 - accuracy: 0.9329
# Epoch 327/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2855 - accuracy: 0.9208
# Epoch 328/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2773 - accuracy: 0.9229
# Epoch 329/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2409 - accuracy: 0.9367
# Epoch 330/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2347 - accuracy: 0.9388
# Epoch 331/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2235 - accuracy: 0.9424
# Epoch 332/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2165 - accuracy: 0.9439
# Epoch 333/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2272 - accuracy: 0.9406
# Epoch 334/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2615 - accuracy: 0.9284
# Epoch 335/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2811 - accuracy: 0.9214
# Epoch 336/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2361 - accuracy: 0.9369
# Epoch 337/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2060 - accuracy: 0.9469
# Epoch 338/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1934 - accuracy: 0.9517
# Epoch 339/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2107 - accuracy: 0.9455
# Epoch 340/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2708 - accuracy: 0.9248
# Epoch 341/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2672 - accuracy: 0.9268
# Epoch 342/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2175 - accuracy: 0.9428
# Epoch 343/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1827 - accuracy: 0.9549
# Epoch 344/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1861 - accuracy: 0.9518
# Epoch 345/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2179 - accuracy: 0.9419
# Epoch 346/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2386 - accuracy: 0.9360
# Epoch 347/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2297 - accuracy: 0.9371
# Epoch 348/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2065 - accuracy: 0.9442
# Epoch 349/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2030 - accuracy: 0.9480
# Epoch 350/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2221 - accuracy: 0.9393
# Epoch 351/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2141 - accuracy: 0.9430
# Epoch 352/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2306 - accuracy: 0.9365
# Epoch 353/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2053 - accuracy: 0.9453
# Epoch 354/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1844 - accuracy: 0.9525
# Epoch 355/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1671 - accuracy: 0.9581
# Epoch 356/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1780 - accuracy: 0.9541
# Epoch 357/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1901 - accuracy: 0.9495
# Epoch 358/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2379 - accuracy: 0.9345
# Epoch 359/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2825 - accuracy: 0.9199
# Epoch 360/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2365 - accuracy: 0.9352
# Epoch 361/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1705 - accuracy: 0.9567
# Epoch 362/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1280 - accuracy: 0.9711
# Epoch 363/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1081 - accuracy: 0.9777
# Epoch 364/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1344 - accuracy: 0.9685
# Epoch 365/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2759 - accuracy: 0.9204
# Epoch 366/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3412 - accuracy: 0.9006
# Epoch 367/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2310 - accuracy: 0.9340
# Epoch 368/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1416 - accuracy: 0.9651
# Epoch 369/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1511 - accuracy: 0.9642
# Epoch 370/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1599 - accuracy: 0.9594
# Epoch 371/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1665 - accuracy: 0.9566
# Epoch 372/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2149 - accuracy: 0.9408
# Epoch 373/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2226 - accuracy: 0.9383
# Epoch 374/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1923 - accuracy: 0.9486
# Epoch 375/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1464 - accuracy: 0.9627
# Epoch 376/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1285 - accuracy: 0.9693
# Epoch 377/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1450 - accuracy: 0.9637
# Epoch 378/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2221 - accuracy: 0.9371
# Epoch 379/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2575 - accuracy: 0.9261
# Epoch 380/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2061 - accuracy: 0.9440
# Epoch 381/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1509 - accuracy: 0.9614
# Epoch 382/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1103 - accuracy: 0.9738
# Epoch 383/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1247 - accuracy: 0.9694
# Epoch 384/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2005 - accuracy: 0.9447
# Epoch 385/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2634 - accuracy: 0.9241
# Epoch 386/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2063 - accuracy: 0.9408
# Epoch 387/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1563 - accuracy: 0.9594
# Epoch 388/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1224 - accuracy: 0.9702
# Epoch 389/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1337 - accuracy: 0.9660
# Epoch 390/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1702 - accuracy: 0.9546
# Epoch 391/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2025 - accuracy: 0.9429
# Epoch 392/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1821 - accuracy: 0.9505
# Epoch 393/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1511 - accuracy: 0.9600
# Epoch 394/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1408 - accuracy: 0.9629
# Epoch 395/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1559 - accuracy: 0.9584
# Epoch 396/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1585 - accuracy: 0.9567
# Epoch 397/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1597 - accuracy: 0.9573
# Epoch 398/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1645 - accuracy: 0.9561
# Epoch 399/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1683 - accuracy: 0.9544
# Epoch 400/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1883 - accuracy: 0.9465
# Epoch 401/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1540 - accuracy: 0.9596
# Epoch 402/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1385 - accuracy: 0.9643
# Epoch 403/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1395 - accuracy: 0.9633
# Epoch 404/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1432 - accuracy: 0.9631
# Epoch 405/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1874 - accuracy: 0.9483
# Epoch 406/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1890 - accuracy: 0.9465
# Epoch 407/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1517 - accuracy: 0.9597
# Epoch 408/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1267 - accuracy: 0.9667
# Epoch 409/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1350 - accuracy: 0.9650
# Epoch 410/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1384 - accuracy: 0.9633
# Epoch 411/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1711 - accuracy: 0.9518
# Epoch 412/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1745 - accuracy: 0.9510
# Epoch 413/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1635 - accuracy: 0.9546
# Epoch 414/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1218 - accuracy: 0.9681
# Epoch 415/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1081 - accuracy: 0.9735
# Epoch 416/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1333 - accuracy: 0.9642
# Epoch 417/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1677 - accuracy: 0.9522
# Epoch 418/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2043 - accuracy: 0.9419
# Epoch 419/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1599 - accuracy: 0.9561
# Epoch 420/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1344 - accuracy: 0.9646
# Epoch 421/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1101 - accuracy: 0.9717
# Epoch 422/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1047 - accuracy: 0.9736
# Epoch 423/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1279 - accuracy: 0.9665
# Epoch 424/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1801 - accuracy: 0.9484
# Epoch 425/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1937 - accuracy: 0.9429
# Epoch 426/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1444 - accuracy: 0.9597
# Epoch 427/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1161 - accuracy: 0.9703
# Epoch 428/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1122 - accuracy: 0.9713
# Epoch 429/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1332 - accuracy: 0.9640
# Epoch 430/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1432 - accuracy: 0.9600
# Epoch 431/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1552 - accuracy: 0.9561
# Epoch 432/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1465 - accuracy: 0.9587
# Epoch 433/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1222 - accuracy: 0.9677
# Epoch 434/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1199 - accuracy: 0.9683
# Epoch 435/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1489 - accuracy: 0.9592
# Epoch 436/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1532 - accuracy: 0.9578
# Epoch 437/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1468 - accuracy: 0.9597
# Epoch 438/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1150 - accuracy: 0.9695
# Epoch 439/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1297 - accuracy: 0.9658
# Epoch 440/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1732 - accuracy: 0.9509
# Epoch 441/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1461 - accuracy: 0.9592
# Epoch 442/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1189 - accuracy: 0.9680
# Epoch 443/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1014 - accuracy: 0.9749
# Epoch 444/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0964 - accuracy: 0.9764
# Epoch 445/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1447 - accuracy: 0.9584
# Epoch 446/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1810 - accuracy: 0.9482
# Epoch 447/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1800 - accuracy: 0.9489
# Epoch 448/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1516 - accuracy: 0.9580
# Epoch 449/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1038 - accuracy: 0.9736
# Epoch 450/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0881 - accuracy: 0.9782
# Epoch 451/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0897 - accuracy: 0.9775
# Epoch 452/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1304 - accuracy: 0.9639
# Epoch 453/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1839 - accuracy: 0.9477
# Epoch 454/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1777 - accuracy: 0.9485
# Epoch 455/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1377 - accuracy: 0.9613
# Epoch 456/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0830 - accuracy: 0.9794
# Epoch 457/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0869 - accuracy: 0.9790
# Epoch 458/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0943 - accuracy: 0.9762
# Epoch 459/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1423 - accuracy: 0.9596
# Epoch 460/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2064 - accuracy: 0.9399
# Epoch 461/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1678 - accuracy: 0.9536
# Epoch 462/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0995 - accuracy: 0.9743
# Epoch 463/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0737 - accuracy: 0.9826
# Epoch 464/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0603 - accuracy: 0.9874
# Epoch 465/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0818 - accuracy: 0.9794
# Epoch 466/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1947 - accuracy: 0.9437
# Epoch 467/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2267 - accuracy: 0.9351
# Epoch 468/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1438 - accuracy: 0.9583
# Epoch 469/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1283 - accuracy: 0.9646
# Epoch 470/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1024 - accuracy: 0.9718
# Epoch 471/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0688 - accuracy: 0.9841
# Epoch 472/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0632 - accuracy: 0.9854
# Epoch 473/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0829 - accuracy: 0.9788
# Epoch 474/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2101 - accuracy: 0.9400
# Epoch 475/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2315 - accuracy: 0.9323
# Epoch 476/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1350 - accuracy: 0.9616
# Epoch 477/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0857 - accuracy: 0.9779
# Epoch 478/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0673 - accuracy: 0.9840
# Epoch 479/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0629 - accuracy: 0.9865
# Epoch 480/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1223 - accuracy: 0.9665
# Epoch 481/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1876 - accuracy: 0.9443
# Epoch 482/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1787 - accuracy: 0.9479
# Epoch 483/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1146 - accuracy: 0.9682
# Epoch 484/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0819 - accuracy: 0.9785
# Epoch 485/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0681 - accuracy: 0.9845
# Epoch 486/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0716 - accuracy: 0.9827
# Epoch 487/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1457 - accuracy: 0.9596
# Epoch 488/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2303 - accuracy: 0.9337
# Epoch 489/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1689 - accuracy: 0.9525
# Epoch 490/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0925 - accuracy: 0.9758
# Epoch 491/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0554 - accuracy: 0.9875
# Epoch 492/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0460 - accuracy: 0.9912
# Epoch 493/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0314 - accuracy: 0.9957
# Epoch 494/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0686 - accuracy: 0.9832
# Epoch 495/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.3427 - accuracy: 0.9027
# Epoch 496/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.2520 - accuracy: 0.9269
# Epoch 497/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.1148 - accuracy: 0.9688
# Epoch 498/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0799 - accuracy: 0.9818
# Epoch 499/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0900 - accuracy: 0.9766
# Epoch 500/500
# 409/409 [==============================] - 6s 14ms/step - loss: 0.0806 - accuracy: 0.9796

# %%
# !mkdir models
model.save("./models/lang-model.h5")

# %% [markdown]
# # Testing the model (text from the book)

# %% [markdown]
# Loading the pre-trained model for testing.

# %%
model = tf.keras.models.load_model("./models/lang-model.h5")

# %% [markdown]
# Creating a text generation function

# %%
# function takes in the model for prediction, the tokenizer (dictionary), the piece of text to be used 
# for prediction and the number of words we want to predict 
def text_gen(model, tokenizer, given_text, num_of_words):
  # text predicted
  final_text = []
  # For each word we want to generate
  for i in range(num_of_words):
    # encoding the text of the first 50 words into ints
    token = tokenizer.texts_to_sequences([given_text])[0]
    # If text is larger than 50 words we keep the last 50 words
    token = pad_sequences([token], maxlen = X.shape[1], truncating='pre')
    # Predicting the probabilities for each word
    y_pred = model.predict(token).argmax(axis=1)

    predicted = ''
    # Finding the index for the predicted word
    for word, index in tokenizer.word_index.items():
      # in the intiger of the predicted word matches an integer index of a word in the dictionary
      if index == y_pred:
        # then the predicted word is assigned the string found in the dictionary at that index
        predicted = word
        break
    # adding the predicted word down into the given text so that the next word can be predicted
    given_text += " "+ predicted
    # also adding the predicted word into a new list of strings that will formulate the final predicted sentence
    final_text.append(predicted)
  # returning the predicted sentence
  return " ".join(final_text)

# %% [markdown]
# Previewing a chuck of text that will be used to predict a small sentence using my model

# %%
sentence_set[276]
# Out:
# 'different i replied rather feebly ah sacr cried poirot is it that you expect her to promenade herself in the streets of london in a cowboy hat or with bare feet and a bunch of curls as an irish colleen always'

# %% [markdown]
# Below we can see the predicted senteced for the above given text

# %%
text_gen(model, tokenizer, sentence_set[276], 20)
# Out:
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 'with you it is the nonessentials remember the case of the dancer valerie saintclair i shrugged my shoulders slightly annoyed'

# %% [markdown]
# Now lets look at the actual text that followed the piece of text that was used to make the prediction.

# %%
sentence_set[315]
# Out:
# 'colleen always with you it is the nonessentials remember the case of the dancer valerie saintclair i shrugged my shoulders slightly annoyed but console yourself mon ami said poirot calming down all cannot be as hercule poirot i know it well'

# %% [markdown]
# # Testing the model (custom text)

# %% [markdown]
# **You can change the text below to anything you like. You can also adjust the number of words you want the model to produce**

# %%
# The piece of text to be given to the model for prediction
my_text = "The gentleman approach the server at the local tavern and waited"
# setting how many words to predict
response_len = 50

# %%
text_gen(model, tokenizer, my_text, response_len)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 'not by with he got down poirot ran nimbly and in such another minutes all the timefor each flat of course in doubt class of disappearance are you late he is met my uncle about halfpast his violet capacity the geniuses his mouth mrs robinson touched having if after many'
